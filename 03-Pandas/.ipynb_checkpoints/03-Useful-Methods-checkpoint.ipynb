# %% [markdown]
# ___
#
# <a href='http://www.pieriandata.com'><img src='../Pierian_Data_Logo.png'/></a>
# ___
# <center><em>Copyright by Pierian Data Inc.</em></center>
# <center><em>For more information, visit us at <a href='http://www.pieriandata.com'>www.pieriandata.com</a></em></center>

# %% [markdown]
# # Useful Methods
#
# Let's cover some useful methods and functions built in to pandas. This is actually just a small sampling of the functions and methods available in Pandas, but they are some of the most commonly used.
# The [documentation](https://pandas.pydata.org/pandas-docs/stable/reference/index.html) is a great resource to continue exploring more methods and functions (we will introduce more further along in the course).
# Here is a list of functions and methods we'll cover here (click on one to jump to that section in this notebook.):
#
# * [apply() method](#apply_method)
# * [apply() with a function](#apply_function)
# * [apply() with a lambda expression](#apply_lambda)
# * [apply() on multiple columns](#apply_multiple)
# * [describe()](#describe)
# * [sort_values()](#sort)
# * [corr()](#corr)
# * [idxmin and idxmax](#idx)
# * [value_counts](#v_c)
# * [replace](#replace)
# * [unique and nunique](#uni)
# * [map](#map)
# * [duplicated and drop_duplicates](#dup)
# * [between](#bet)
# * [sample](#sample)
# * [nlargest](#n)
#
# Make sure to view the video lessons to get the full explanation!

# %% [markdown]
# <a id='apply_method'></a>
#
# ## The .apply() method
#
# Here we will learn about a very useful method known as **apply** on a DataFrame. This allows us to apply and broadcast custom functions on a DataFrame column

# %%
import pandas as pd
import numpy as np

# %%
df = pd.read_csv('tips.csv')

# %%
df.head()
# Out:
#    total_bill   tip     sex smoker  day    time  size  price_per_person  \
# 0       16.99  1.01  Female     No  Sun  Dinner     2              8.49
# 1       10.34  1.66    Male     No  Sun  Dinner     3              3.45
# 2       21.01  3.50    Male     No  Sun  Dinner     3              7.00
# 3       23.68  3.31    Male     No  Sun  Dinner     2             11.84
# 4       24.59  3.61  Female     No  Sun  Dinner     4              6.15
#
#            Payer Name         CC Number Payment ID
# 0  Christy Cunningham  3560325168603410    Sun2959
# 1      Douglas Tucker  4478071379779230    Sun4608
# 2      Travis Walters  6011812112971322    Sun4458
# 3    Nathaniel Harris  4676137647685994    Sun5260
# 4        Tonya Carter  4832732618637221    Sun2251

# %% [markdown]
# <a id='apply_function'></a>
# ### apply with a function

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 244 entries, 0 to 243
# Data columns (total 11 columns):
#  #   Column            Non-Null Count  Dtype
# ---  ------            --------------  -----
#  0   total_bill        244 non-null    float64
#  1   tip               244 non-null    float64
#  2   sex               244 non-null    object
#  3   smoker            244 non-null    object
#  4   day               244 non-null    object
#  5   time              244 non-null    object
#  6   size              244 non-null    int64
#  7   price_per_person  244 non-null    float64
#  8   Payer Name        244 non-null    object
#  9   CC Number         244 non-null    int64
#  10  Payment ID        244 non-null    object
# dtypes: float64(3), int64(2), object(6)
# memory usage: 21.1+ KB

# %%
def last_four(num):
    return str(num)[-4:]

# %%
df['CC Number'][0]
# Out:
# 3560325168603410

# %%
last_four(3560325168603410)
# Out:
# '3410'

# %%
df['last_four'] = df['CC Number'].apply(lambda num: str(num)[-4:])

# %%
df.head()
# Out:
#    total_bill   tip     sex smoker  day    time  size  price_per_person  \
# 0       16.99  1.01  Female     No  Sun  Dinner     2              8.49
# 1       10.34  1.66    Male     No  Sun  Dinner     3              3.45
# 2       21.01  3.50    Male     No  Sun  Dinner     3              7.00
# 3       23.68  3.31    Male     No  Sun  Dinner     2             11.84
# 4       24.59  3.61  Female     No  Sun  Dinner     4              6.15
#
#            Payer Name         CC Number Payment ID last_four
# 0  Christy Cunningham  3560325168603410    Sun2959      3410
# 1      Douglas Tucker  4478071379779230    Sun4608      9230
# 2      Travis Walters  6011812112971322    Sun4458      1322
# 3    Nathaniel Harris  4676137647685994    Sun5260      5994
# 4        Tonya Carter  4832732618637221    Sun2251      7221

# %% [markdown]
# ### Using .apply() with more complex functions

# %%
df['total_bill'].mean()
# Out:
# 19.785942622950824

# %%
def yelp(price):
    if price < 10:
        return '$'
    elif price >= 10 and price < 30:
        return '$$'
    else:
        return '$$$'

# %%
df['Expensive'] = df['total_bill'].apply(yelp)

# %%
# df

# %% [markdown]
# <a id='apply_lambda'></a>
# ### apply with lambda

# %%
def simple(num):
    return num*2

# %%
lambda num: num*2
# Out:
# <function __main__.<lambda>(num)>

# %%
df['total_bill'].apply(lambda bill:bill*0.18)
# Out:
# 0      3.0582
# 1      1.8612
# 2      3.7818
# 3      4.2624
# 4      4.4262
#         ...
# 239    5.2254
# 240    4.8924
# 241    4.0806
# 242    3.2076
# 243    3.3804
# Name: total_bill, Length: 244, dtype: float64

# %% [markdown]
# <a id='apply_multiple'></a>
# ## apply that uses multiple columns
#
# Note, there are several ways to do this:
#
# https://stackoverflow.com/questions/19914937/applying-function-with-multiple-arguments-to-create-a-new-pandas-column

# %%
df.head()
# Out:
#    total_bill   tip     sex smoker  day    time  size  price_per_person  \
# 0       16.99  1.01  Female     No  Sun  Dinner     2              8.49
# 1       10.34  1.66    Male     No  Sun  Dinner     3              3.45
# 2       21.01  3.50    Male     No  Sun  Dinner     3              7.00
# 3       23.68  3.31    Male     No  Sun  Dinner     2             11.84
# 4       24.59  3.61  Female     No  Sun  Dinner     4              6.15
#
#            Payer Name         CC Number Payment ID last_four Expensive
# 0  Christy Cunningham  3560325168603410    Sun2959      3410        $$
# 1      Douglas Tucker  4478071379779230    Sun4608      9230        $$
# 2      Travis Walters  6011812112971322    Sun4458      1322        $$
# 3    Nathaniel Harris  4676137647685994    Sun5260      5994        $$
# 4        Tonya Carter  4832732618637221    Sun2251      7221        $$

# %%
def quality(total_bill,tip):
    if tip/total_bill  > 0.10:
        return "Generous"
    else:
        return "Other"

# %%
df['Tip Quality'] = df[['total_bill','tip']].apply(lambda df: quality(df['total_bill'], df['tip']), axis=1)

# %%
df.head()
# Out:
#    total_bill   tip     sex smoker  day    time  size  price_per_person  \
# 0       16.99  1.01  Female     No  Sun  Dinner     2              8.49
# 1       10.34  1.66    Male     No  Sun  Dinner     3              3.45
# 2       21.01  3.50    Male     No  Sun  Dinner     3              7.00
# 3       23.68  3.31    Male     No  Sun  Dinner     2             11.84
# 4       24.59  3.61  Female     No  Sun  Dinner     4              6.15
#
#            Payer Name         CC Number Payment ID last_four Expensive  \
# 0  Christy Cunningham  3560325168603410    Sun2959      3410        $$
# 1      Douglas Tucker  4478071379779230    Sun4608      9230        $$
# 2      Travis Walters  6011812112971322    Sun4458      1322        $$
# 3    Nathaniel Harris  4676137647685994    Sun5260      5994        $$
# 4        Tonya Carter  4832732618637221    Sun2251      7221        $$
#
#   Tip Quality
# 0       Other
# 1    Generous
# 2    Generous
# 3    Generous
# 4    Generous

# %%
import numpy as np

# %%
df['Quality'] = np.vectorize(quality)(df['total_bill'], df['tip'])

# %%
df.head()
# Out:
#    total_bill   tip     sex smoker  day    time  size  price_per_person  \
# 0       16.99  1.01  Female     No  Sun  Dinner     2              8.49
# 1       10.34  1.66    Male     No  Sun  Dinner     3              3.45
# 2       21.01  3.50    Male     No  Sun  Dinner     3              7.00
# 3       23.68  3.31    Male     No  Sun  Dinner     2             11.84
# 4       24.59  3.61  Female     No  Sun  Dinner     4              6.15
#
#            Payer Name         CC Number Payment ID last_four Expensive  \
# 0  Christy Cunningham  3560325168603410    Sun2959      3410        $$
# 1      Douglas Tucker  4478071379779230    Sun4608      9230        $$
# 2      Travis Walters  6011812112971322    Sun4458      1322        $$
# 3    Nathaniel Harris  4676137647685994    Sun5260      5994        $$
# 4        Tonya Carter  4832732618637221    Sun2251      7221        $$
#
#   Tip Quality   Quality
# 0       Other     Other
# 1    Generous  Generous
# 2    Generous  Generous
# 3    Generous  Generous
# 4    Generous  Generous

# %% [markdown]
# So, which one is faster?

# %%
import timeit 
  
# code snippet to be executed only once 
setup = '''
import numpy as np
import pandas as pd
df = pd.read_csv('tips.csv')
def quality(total_bill,tip):
    if tip/total_bill  > 0.50:
        return "Generous"
    else:
        return "Other"
'''
  
# code snippet whose execution time is to be measured 
stmt_one = ''' 
df['Tip Quality'] = df[['total_bill','tip']].apply(lambda df: quality(df['total_bill'],df['tip']),axis=1)
'''

stmt_two = '''
df['Tip Quality'] = np.vectorize(quality)(df['total_bill'], df['tip'])
'''

# %%
timeit.timeit(setup = setup, 
                    stmt = stmt_one, 
                    number = 500)
# Out:
# 8.156422000000006

# %%
timeit.timeit(setup = setup, 
                    stmt = stmt_two, 
                    number = 500)
# Out:
# 0.9490332999999964

# %% [markdown]
# Wow! Vectorization is much faster! Keep **np.vectorize()** in mind for the future.
#
# Full Details:
# https://docs.scipy.org/doc/numpy/reference/generated/numpy.vectorize.html

# %% [markdown]
# <a id='describe'></a>
# ### df.describe for statistical summaries

# %%
df.describe()
# Out:
#        total_bill         tip        size  price_per_person     CC Number
# count  244.000000  244.000000  244.000000        244.000000  2.440000e+02
# mean    19.785943    2.998279    2.569672          7.888197  2.563496e+15
# std      8.902412    1.383638    0.951100          2.914234  2.369340e+15
# min      3.070000    1.000000    1.000000          2.880000  6.040679e+10
# 25%     13.347500    2.000000    2.000000          5.800000  3.040731e+13
# 50%     17.795000    2.900000    2.000000          7.255000  3.525318e+15
# 75%     24.127500    3.562500    3.000000          9.390000  4.553675e+15
# max     50.810000   10.000000    6.000000         20.270000  6.596454e+15

# %%
df.describe().transpose()
# Out:
#                   count          mean           std           min  \
# total_bill        244.0  1.978594e+01  8.902412e+00  3.070000e+00
# tip               244.0  2.998279e+00  1.383638e+00  1.000000e+00
# size              244.0  2.569672e+00  9.510998e-01  1.000000e+00
# price_per_person  244.0  7.888197e+00  2.914234e+00  2.880000e+00
# CC Number         244.0  2.563496e+15  2.369340e+15  6.040679e+10
#
#                            25%           50%           75%           max
# total_bill        1.334750e+01  1.779500e+01  2.412750e+01  5.081000e+01
# tip               2.000000e+00  2.900000e+00  3.562500e+00  1.000000e+01
# size              2.000000e+00  2.000000e+00  3.000000e+00  6.000000e+00
# price_per_person  5.800000e+00  7.255000e+00  9.390000e+00  2.027000e+01
# CC Number         3.040731e+13  3.525318e+15  4.553675e+15  6.596454e+15

# %% [markdown]
# <a id='sort'></a>
# ### sort_values()

# %%
df.sort_values(['tip', 'size'])
# Out:
#      total_bill    tip     sex smoker   day    time  size  price_per_person  \
# 67         3.07   1.00  Female    Yes   Sat  Dinner     1              3.07
# 111        7.25   1.00  Female     No   Sat  Dinner     1              7.25
# 92         5.75   1.00  Female    Yes   Fri  Dinner     2              2.88
# 236       12.60   1.00    Male    Yes   Sat  Dinner     2              6.30
# 0         16.99   1.01  Female     No   Sun  Dinner     2              8.49
# ..          ...    ...     ...    ...   ...     ...   ...               ...
# 141       34.30   6.70    Male     No  Thur   Lunch     6              5.72
# 59        48.27   6.73    Male     No   Sat  Dinner     4             12.07
# 23        39.42   7.58    Male     No   Sat  Dinner     4              9.86
# 212       48.33   9.00    Male     No   Sat  Dinner     4             12.08
# 170       50.81  10.00    Male    Yes   Sat  Dinner     3             16.94
#
#              Payer Name         CC Number Payment ID last_four Expensive  \
# 67        Tiffany Brock  4359488526995267    Sat3455      5267         $
# 111         Terri Jones  3559221007826887    Sat4801      6887         $
# 92         Leah Ramirez  3508911676966392    Fri3780      6392         $
# 236       Matthew Myers  3543676378973965    Sat5032      3965        $$
# 0    Christy Cunningham  3560325168603410    Sun2959      3410        $$
# ..                  ...               ...        ...       ...       ...
# 141      Steven Carlson  3526515703718508   Thur1025      8508       $$$
# 59          Brian Ortiz  6596453823950595    Sat8139      0595       $$$
# 23       Lance Peterson  3542584061609808     Sat239      9808       $$$
# 212     Alex Williamson      676218815212    Sat4590      5212       $$$
# 170       Gregory Clark  5473850968388236    Sat1954      8236       $$$
#
#     Tip Quality   Quality
# 67     Generous  Generous
# 111    Generous  Generous
# 92     Generous  Generous
# 236          Ok     Other
# 0            Ok     Other
# ..          ...       ...
# 141    Generous  Generous
# 59     Generous  Generous
# 23     Generous  Generous
# 212    Generous  Generous
# 170    Generous  Generous
#
# [244 rows x 15 columns]

# %%
df.iloc[df['total_bill'].idxmin()]
# Out:
# total_bill                      3.07
# tip                              1.0
# sex                           Female
# smoker                           Yes
# day                              Sat
# time                          Dinner
# size                               1
# price_per_person                3.07
# Payer Name             Tiffany Brock
# CC Number           4359488526995267
# Payment ID                   Sat3455
# last_four                       5267
# Expensive                          $
# Tip Quality                 Generous
# Quality                     Generous
# Name: 67, dtype: object

# %%
# Helpful if you want to reorder after a sort
# https://stackoverflow.com/questions/13148429/how-to-change-the-order-of-dataframe-columns
df.sort_values(['tip','size'])
# Out:
#      total_bill    tip     sex smoker   day    time  size  price_per_person  \
# 67         3.07   1.00  Female    Yes   Sat  Dinner     1              3.07
# 111        7.25   1.00  Female     No   Sat  Dinner     1              7.25
# 92         5.75   1.00  Female    Yes   Fri  Dinner     2              2.88
# 236       12.60   1.00    Male    Yes   Sat  Dinner     2              6.30
# 0         16.99   1.01  Female     No   Sun  Dinner     2              8.49
# ..          ...    ...     ...    ...   ...     ...   ...               ...
# 141       34.30   6.70    Male     No  Thur   Lunch     6              5.72
# 59        48.27   6.73    Male     No   Sat  Dinner     4             12.07
# 23        39.42   7.58    Male     No   Sat  Dinner     4              9.86
# 212       48.33   9.00    Male     No   Sat  Dinner     4             12.08
# 170       50.81  10.00    Male    Yes   Sat  Dinner     3             16.94
#
#              Payer Name         CC Number Payment ID last_four Expensive  \
# 67        Tiffany Brock  4359488526995267    Sat3455      5267         $
# 111         Terri Jones  3559221007826887    Sat4801      6887         $
# 92         Leah Ramirez  3508911676966392    Fri3780      6392         $
# 236       Matthew Myers  3543676378973965    Sat5032      3965        $$
# 0    Christy Cunningham  3560325168603410    Sun2959      3410        $$
# ..                  ...               ...        ...       ...       ...
# 141      Steven Carlson  3526515703718508   Thur1025      8508       $$$
# 59          Brian Ortiz  6596453823950595    Sat8139      0595       $$$
# 23       Lance Peterson  3542584061609808     Sat239      9808       $$$
# 212     Alex Williamson      676218815212    Sat4590      5212       $$$
# 170       Gregory Clark  5473850968388236    Sat1954      8236       $$$
#
#     Tip Quality   Quality
# 67     Generous  Generous
# 111    Generous  Generous
# 92     Generous  Generous
# 236       Other     Other
# 0         Other     Other
# ..          ...       ...
# 141    Generous  Generous
# 59     Generous  Generous
# 23     Generous  Generous
# 212    Generous  Generous
# 170    Generous  Generous
#
# [244 rows x 15 columns]

# %% [markdown]
# <a id='corr'></a>
# ## df.corr() for correlation checks
#
# [Wikipedia on Correlation](https://en.wikipedia.org/wiki/Correlation_and_dependence)

# %%
df.corr()
# Out:
#                   total_bill       tip      size  price_per_person  CC Number
# total_bill          1.000000  0.675734  0.598315          0.647554   0.104576
# tip                 0.675734  1.000000  0.489299          0.347405   0.110857
# size                0.598315  0.489299  1.000000         -0.175359  -0.030239
# price_per_person    0.647554  0.347405 -0.175359          1.000000   0.135240
# CC Number           0.104576  0.110857 -0.030239          0.135240   1.000000

# %%
df[['total_bill','tip']].corr()
# Out:
#             total_bill       tip
# total_bill    1.000000  0.675734
# tip           0.675734  1.000000

# %% [markdown]
# <a id='idx'></a>
# ### idxmin and idxmax

# %%
df.head()
# Out:
#    total_bill   tip     sex smoker  day    time  size  price_per_person  \
# 0       16.99  1.01  Female     No  Sun  Dinner     2              8.49
# 1       10.34  1.66    Male     No  Sun  Dinner     3              3.45
# 2       21.01  3.50    Male     No  Sun  Dinner     3              7.00
# 3       23.68  3.31    Male     No  Sun  Dinner     2             11.84
# 4       24.59  3.61  Female     No  Sun  Dinner     4              6.15
#
#            Payer Name         CC Number Payment ID last_four Expensive  \
# 0  Christy Cunningham  3560325168603410    Sun2959      3410        $$
# 1      Douglas Tucker  4478071379779230    Sun4608      9230        $$
# 2      Travis Walters  6011812112971322    Sun4458      1322        $$
# 3    Nathaniel Harris  4676137647685994    Sun5260      5994        $$
# 4        Tonya Carter  4832732618637221    Sun2251      7221        $$
#
#   Tip Quality   Quality
# 0       Other     Other
# 1    Generous  Generous
# 2    Generous  Generous
# 3    Generous  Generous
# 4    Generous  Generous

# %%
df['total_bill'].max()
# Out:
# 50.81

# %%
df['total_bill'].idxmax()
# Out:
# 170

# %%
df['total_bill'].idxmin()
# Out:
# 67

# %%
df.iloc[67]
# Out:
# total_bill                      3.07
# tip                              1.0
# sex                           Female
# smoker                           Yes
# day                              Sat
# time                          Dinner
# size                               1
# price_per_person                3.07
# Payer Name             Tiffany Brock
# CC Number           4359488526995267
# Payment ID                   Sat3455
# last_four                       5267
# Expensive                          $
# Tip Quality                 Generous
# Quality                     Generous
# Name: 67, dtype: object

# %%
df.iloc[170]
# Out:
# total_bill                     50.81
# tip                             10.0
# sex                             Male
# smoker                           Yes
# day                              Sat
# time                          Dinner
# size                               3
# price_per_person               16.94
# Payer Name             Gregory Clark
# CC Number           5473850968388236
# Payment ID                   Sat1954
# last_four                       8236
# Expensive                        $$$
# Tip Quality                 Generous
# Quality                     Generous
# Name: 170, dtype: object

# %% [markdown]
# <a id='v_c'></a>
# ### value_counts
#
# Nice method to quickly get a count per category. Only makes sense on categorical columns.

# %%
df.head()
# Out:
#    total_bill   tip     sex smoker  day    time  size  price_per_person  \
# 0       16.99  1.01  Female     No  Sun  Dinner     2              8.49
# 1       10.34  1.66    Male     No  Sun  Dinner     3              3.45
# 2       21.01  3.50    Male     No  Sun  Dinner     3              7.00
# 3       23.68  3.31    Male     No  Sun  Dinner     2             11.84
# 4       24.59  3.61  Female     No  Sun  Dinner     4              6.15
#
#            Payer Name         CC Number Payment ID last_four Expensive  \
# 0  Christy Cunningham  3560325168603410    Sun2959      3410        $$
# 1      Douglas Tucker  4478071379779230    Sun4608      9230        $$
# 2      Travis Walters  6011812112971322    Sun4458      1322        $$
# 3    Nathaniel Harris  4676137647685994    Sun5260      5994        $$
# 4        Tonya Carter  4832732618637221    Sun2251      7221        $$
#
#   Tip Quality   Quality
# 0       Other     Other
# 1    Generous  Generous
# 2    Generous  Generous
# 3    Generous  Generous
# 4    Generous  Generous

# %%
df['sex'].value_counts()
# Out:
# Male      157
# Female     87
# Name: sex, dtype: int64

# %% [markdown]
# <a id='replace'></a>
#
# ### replace
#
# Quickly replace values with another one.

# %%
df.head()
# Out:
#    total_bill   tip     sex smoker  day    time  size  price_per_person  \
# 0       16.99  1.01  Female     No  Sun  Dinner     2              8.49
# 1       10.34  1.66    Male     No  Sun  Dinner     3              3.45
# 2       21.01  3.50    Male     No  Sun  Dinner     3              7.00
# 3       23.68  3.31    Male     No  Sun  Dinner     2             11.84
# 4       24.59  3.61  Female     No  Sun  Dinner     4              6.15
#
#            Payer Name         CC Number Payment ID last_four Expensive  \
# 0  Christy Cunningham  3560325168603410    Sun2959      3410        $$
# 1      Douglas Tucker  4478071379779230    Sun4608      9230        $$
# 2      Travis Walters  6011812112971322    Sun4458      1322        $$
# 3    Nathaniel Harris  4676137647685994    Sun5260      5994        $$
# 4        Tonya Carter  4832732618637221    Sun2251      7221        $$
#
#   Tip Quality   Quality
# 0       Other     Other
# 1    Generous  Generous
# 2    Generous  Generous
# 3    Generous  Generous
# 4    Generous  Generous

# %%
df['Tip Quality'].replace(to_replace='Other',value='Ok')
# Out:
# 0            Ok
# 1      Generous
# 2      Generous
# 3      Generous
# 4      Generous
#          ...
# 239    Generous
# 240          Ok
# 241          Ok
# 242          Ok
# 243    Generous
# Name: Tip Quality, Length: 244, dtype: object

# %%
df[['Tip Quality', 'Quality']] = df[['Tip Quality', 'Quality']].replace(to_replace='Other',value='Ok')
df['sex'] = df['sex'].replace(['Female', 'Male'], ['F', 'M'])

# %%
df.head()
# Out:
#    total_bill   tip sex smoker  day    time  size  price_per_person  \
# 0       16.99  1.01   F     No  Sun  Dinner     2              8.49
# 1       10.34  1.66   M     No  Sun  Dinner     3              3.45
# 2       21.01  3.50   M     No  Sun  Dinner     3              7.00
# 3       23.68  3.31   M     No  Sun  Dinner     2             11.84
# 4       24.59  3.61   F     No  Sun  Dinner     4              6.15
#
#            Payer Name         CC Number Payment ID last_four Expensive  \
# 0  Christy Cunningham  3560325168603410    Sun2959      3410        $$
# 1      Douglas Tucker  4478071379779230    Sun4608      9230        $$
# 2      Travis Walters  6011812112971322    Sun4458      1322        $$
# 3    Nathaniel Harris  4676137647685994    Sun5260      5994        $$
# 4        Tonya Carter  4832732618637221    Sun2251      7221        $$
#
#   Tip Quality   Quality
# 0          Ok        Ok
# 1    Generous  Generous
# 2    Generous  Generous
# 3    Generous  Generous
# 4    Generous  Generous

# %% [markdown]
# <a id='uni'></a>
# ### unique

# %%
df['size'].unique()
# Out:
# array([2, 3, 4, 1, 6, 5], dtype=int64)

# %%
df['size'].nunique()
# Out:
# 6

# %%
df['time'].unique()
# Out:
# array(['Dinner', 'Lunch'], dtype=object)

# %% [markdown]
# <a id='map'></a>
# ### map

# %%
my_map = {'Dinner':'D','Lunch':'L'}

# %%
df['time'] = df['time'].map(my_map)

# %%
df.head()
# Out:
#    total_bill   tip sex smoker  day time  size  price_per_person  \
# 0       16.99  1.01   F     No  Sun    D     2              8.49
# 1       10.34  1.66   M     No  Sun    D     3              3.45
# 2       21.01  3.50   M     No  Sun    D     3              7.00
# 3       23.68  3.31   M     No  Sun    D     2             11.84
# 4       24.59  3.61   F     No  Sun    D     4              6.15
#
#            Payer Name         CC Number Payment ID last_four Expensive  \
# 0  Christy Cunningham  3560325168603410    Sun2959      3410        $$
# 1      Douglas Tucker  4478071379779230    Sun4608      9230        $$
# 2      Travis Walters  6011812112971322    Sun4458      1322        $$
# 3    Nathaniel Harris  4676137647685994    Sun5260      5994        $$
# 4        Tonya Carter  4832732618637221    Sun2251      7221        $$
#
#   Tip Quality   Quality
# 0          Ok        Ok
# 1    Generous  Generous
# 2    Generous  Generous
# 3    Generous  Generous
# 4    Generous  Generous

# %% [markdown]
# <a id='dup'></a>
# ## Duplicates
#
# ### .duplicated() and .drop_duplicates()

# %%
# Returns True for the 1st instance of a duplicated row
df.duplicated()
# Out:
# 0      False
# 1      False
# 2      False
# 3      False
# 4      False
#        ...
# 239    False
# 240    False
# 241    False
# 242    False
# 243    False
# Length: 244, dtype: bool

# %%
simple_df = pd.DataFrame([1,2,2],['a','b','c'])

# %%
simple_df
# Out:
#    0
# a  1
# b  2
# c  2

# %%
simple_df.duplicated()
# Out:
# a    False
# b    False
# c     True
# dtype: bool

# %%
simple_df.drop_duplicates()
# Out:
#    0
# a  1
# b  2

# %% [markdown]
# <a id='bet'></a>
# ## between
#
# left: A scalar value that defines the left boundary
# right: A scalar value that defines the right boundary
# inclusive: A Boolean value which is True by default. If False, it excludes the two passed arguments while checking.

# %%
df['total_bill'].between(10,20,inclusive=True)
# Out:
# C:\Users\Athirson\AppData\Local\Temp/ipykernel_10740/4013148072.py:1: FutureWarning: Boolean inputs to the `inclusive` argument are deprecated infavour of `both` or `neither`.
#   df['total_bill'].between(10,20,inclusive=True)
# 0       True
# 1       True
# 2      False
# 3      False
# 4      False
#        ...
# 239    False
# 240    False
# 241    False
# 242     True
# 243     True
# Name: total_bill, Length: 244, dtype: bool

# %%
df[df['total_bill'].between(10,20,inclusive=True)]
# Out:
# C:\Users\Athirson\AppData\Local\Temp/ipykernel_10740/1152120679.py:1: FutureWarning: Boolean inputs to the `inclusive` argument are deprecated infavour of `both` or `neither`.
#   df[df['total_bill'].between(10,20,inclusive=True)]
#      total_bill   tip     sex smoker   day    time  size  price_per_person  \
# 0         16.99  1.01  Female     No   Sun  Dinner     2              8.49
# 1         10.34  1.66    Male     No   Sun  Dinner     3              3.45
# 8         15.04  1.96    Male     No   Sun  Dinner     2              7.52
# 9         14.78  3.23    Male     No   Sun  Dinner     2              7.39
# 10        10.27  1.71    Male     No   Sun  Dinner     2              5.14
# ..          ...   ...     ...    ...   ...     ...   ...               ...
# 234       15.53  3.00    Male    Yes   Sat  Dinner     2              7.76
# 235       10.07  1.25    Male     No   Sat  Dinner     2              5.04
# 236       12.60  1.00    Male    Yes   Sat  Dinner     2              6.30
# 242       17.82  1.75    Male     No   Sat  Dinner     2              8.91
# 243       18.78  3.00  Female     No  Thur  Dinner     2              9.39
#
#              Payer Name         CC Number Payment ID last_four Expensive  \
# 0    Christy Cunningham  3560325168603410    Sun2959      3410        $$
# 1        Douglas Tucker  4478071379779230    Sun4608      9230        $$
# 8       Joseph Mcdonald  3522866365840377    Sun6820      0377        $$
# 9         Jerome Abbott  3532124519049786    Sun3775      9786        $$
# 10        William Riley      566287581219    Sun2546      1219        $$
# ..                  ...               ...        ...       ...       ...
# 234       Tracy Douglas  4097938155941930    Sat7220      1930        $$
# 235       Sean Gonzalez  3534021246117605    Sat4615      7605        $$
# 236       Matthew Myers  3543676378973965    Sat5032      3965        $$
# 242        Dennis Dixon     4375220550950      Sat17      0950        $$
# 243     Michelle Hardin  3511451626698139    Thur672      8139        $$
#
#     Tip Quality   Quality
# 0            Ok     Other
# 1      Generous  Generous
# 8      Generous  Generous
# 9      Generous  Generous
# 10     Generous  Generous
# ..          ...       ...
# 234    Generous  Generous
# 235    Generous  Generous
# 236          Ok     Other
# 242          Ok     Other
# 243    Generous  Generous
#
# [130 rows x 15 columns]

# %% [markdown]
# <a id='sample'></a>
# ## sample

# %%
df.sample(5)
# Out:
#      total_bill   tip sex smoker   day time  size  price_per_person  \
# 147       11.87  1.63   F     No  Thur    L     2              5.94
# 44        30.40  5.60   M     No   Sun    D     4              7.60
# 0         16.99  1.01   F     No   Sun    D     2              8.49
# 223       15.98  3.00   F     No   Fri    L     3              5.33
# 220       12.16  2.20   M    Yes   Fri    L     2              6.08
#
#              Payer Name         CC Number Payment ID last_four Expensive  \
# 147  Annette Cunningham      675937746864   Thur4780      6864        $$
# 44          Todd Cooper      503846761263    Sun2274      1263       $$$
# 0    Christy Cunningham  3560325168603410    Sun2959      3410        $$
# 223         Mary Rivera  5343428579353069    Fri6014      3069        $$
# 220       Ricky Johnson   213109508670736    Fri4607      0736        $$
#
#     Tip Quality   Quality
# 147    Generous  Generous
# 44     Generous  Generous
# 0            Ok        Ok
# 223    Generous  Generous
# 220    Generous  Generous

# %%
df.sample(frac=0.1)
# Out:
#      total_bill   tip     sex smoker   day    time  size  price_per_person  \
# 39        31.27  5.00    Male     No   Sat  Dinner     3             10.42
# 28        21.70  4.30    Male     No   Sat  Dinner     2             10.85
# 119       24.08  2.92  Female     No  Thur   Lunch     4              6.02
# 46        22.23  5.00    Male     No   Sun  Dinner     2             11.12
# 31        18.35  2.50    Male     No   Sat  Dinner     4              4.59
# 197       43.11  5.00  Female    Yes  Thur   Lunch     4             10.78
# 1         10.34  1.66    Male     No   Sun  Dinner     3              3.45
# 203       16.40  2.50  Female    Yes  Thur   Lunch     2              8.20
# 70        12.02  1.97    Male     No   Sat  Dinner     2              6.01
# 156       48.17  5.00    Male     No   Sun  Dinner     6              8.03
# 165       24.52  3.48    Male     No   Sun  Dinner     3              8.17
# 190       15.69  1.50    Male    Yes   Sun  Dinner     2              7.84
# 76        17.92  3.08    Male    Yes   Sat  Dinner     2              8.96
# 61        13.81  2.00    Male    Yes   Sat  Dinner     2              6.90
# 209       12.76  2.23  Female    Yes   Sat  Dinner     2              6.38
# 221       13.42  3.48  Female    Yes   Fri   Lunch     2              6.71
# 9         14.78  3.23    Male     No   Sun  Dinner     2              7.39
# 150       14.07  2.50    Male     No   Sun  Dinner     2              7.04
# 68        20.23  2.01    Male     No   Sat  Dinner     2             10.12
# 193       15.48  2.02    Male    Yes  Thur   Lunch     2              7.74
# 130       19.08  1.50    Male     No  Thur   Lunch     2              9.54
# 234       15.53  3.00    Male    Yes   Sat  Dinner     2              7.76
# 145        8.35  1.50  Female     No  Thur   Lunch     2              4.18
# 87        18.28  4.00    Male     No  Thur   Lunch     2              9.14
#
#                 Payer Name         CC Number Payment ID last_four Expensive  \
# 39       Mr. Brandon Berry  6011525851069856    Sat6373      9856       $$$
# 28           David Collier  5529694315416009    Sat3697      6009        $$
# 119         Melanie Jordan      676212062720   Thur8063      2720        $$
# 46          Joshua Gilmore     4292072734899    Sun7097      4899        $$
# 31          Danny Santiago      630415546013    Sat4947      6013        $$
# 197            Brooke Soto  5544902205760175   Thur9313      0175       $$$
# 1           Douglas Tucker  4478071379779230    Sun4608      9230        $$
# 203            Toni Brooks  3582289985920239   Thur7770      0239        $$
# 70               Max Brown   213139760497718    Sat2100      7718        $$
# 156          Ryan Gonzales  3523151482063321    Sun7518      3321       $$$
# 165           Jacob Hansen     4031116007387    Sun9043      7387        $$
# 190           Riley Barnes   180053549128800    Sun5104      8800        $$
# 76              Mark Smith      676188485350    Sat9908      5350        $$
# 61          Ryan Hernandez     4766834726806    Sat3030      6806        $$
# 209       Sarah Cunningham   341876516331163    Sat1274      1163        $$
# 221         Leslie Kaufman   379437981958785    Fri7511      8785        $$
# 9            Jerome Abbott  3532124519049786    Sun3775      9786        $$
# 150              Luke Rice  4813617017359506    Sun8863      9506        $$
# 68   Mr. Travis Bailey Jr.       60406789937     Sat561      9937        $$
# 193       Raymond Sullivan   180068856139315    Thur606      9315        $$
# 130            Seth Sexton   213113680829581   Thur1446      9581        $$
# 234          Tracy Douglas  4097938155941930    Sat7220      1930        $$
# 145              Amy Young     4285454264477   Thur9331      4477         $
# 87         Donald Williams  5363745772301404   Thur3636      1404        $$
#
#     Tip Quality   Quality
# 39     Generous  Generous
# 28     Generous  Generous
# 119    Generous  Generous
# 46     Generous  Generous
# 31     Generous  Generous
# 197    Generous  Generous
# 1      Generous  Generous
# 203    Generous  Generous
# 70     Generous  Generous
# 156    Generous  Generous
# 165    Generous  Generous
# 190          Ok     Other
# 76     Generous  Generous
# 61     Generous  Generous
# 209    Generous  Generous
# 221    Generous  Generous
# 9      Generous  Generous
# 150    Generous  Generous
# 68           Ok     Other
# 193    Generous  Generous
# 130          Ok     Other
# 234    Generous  Generous
# 145    Generous  Generous
# 87     Generous  Generous

# %% [markdown]
# <a id='n'></a>
# ## nlargest and nsmallest

# %%
df.nlargest(4,'size')
# Out:
#      total_bill  tip sex smoker   day time  size  price_per_person  \
# 125       29.80  4.2   F     No  Thur    L     6              4.97
# 141       34.30  6.7   M     No  Thur    L     6              5.72
# 143       27.05  5.0   F     No  Thur    L     6              4.51
# 156       48.17  5.0   M     No   Sun    D     6              8.03
#
#          Payer Name         CC Number Payment ID last_four Expensive  \
# 125  Angela Sanchez      503857080488   Thur3948      0488        $$
# 141  Steven Carlson  3526515703718508   Thur1025      8508       $$$
# 143    Regina Jones     4311048695487   Thur6179      5487        $$
# 156   Ryan Gonzales  3523151482063321    Sun7518      3321       $$$
#
#     Tip Quality   Quality
# 125    Generous  Generous
# 141    Generous  Generous
# 143    Generous  Generous
# 156    Generous  Generous

# %%
df.nsmallest(4, 'size')
# Out:
#      total_bill   tip sex smoker   day time  size  price_per_person  \
# 67         3.07  1.00   F    Yes   Sat    D     1              3.07
# 82        10.07  1.83   F     No  Thur    L     1             10.07
# 111        7.25  1.00   F     No   Sat    D     1              7.25
# 222        8.58  1.92   M    Yes   Fri    L     1              8.58
#
#          Payer Name         CC Number Payment ID last_four Expensive  \
# 67    Tiffany Brock  4359488526995267    Sat3455      5267         $
# 82      Julie Moody      630413282843   Thur4909      2843        $$
# 111     Terri Jones  3559221007826887    Sat4801      6887         $
# 222  Jason Lawrence  3505302934650403    Fri6624      0403         $
#
#     Tip Quality   Quality
# 67     Generous  Generous
# 82     Generous  Generous
# 111    Generous  Generous
# 222    Generous  Generous

# %% [markdown]
# ----
